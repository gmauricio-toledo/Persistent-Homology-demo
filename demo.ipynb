# %%
import numpy as np
import matplotlib.pyplot as plt
from ripser import Rips

# %% [markdown]
# Probemos con un conjunto de puntos aleatorio

# %%
data = np.random.random((100,2))

data.shape

plt.figure(dpi=120)
plt.scatter(data[:,0],data[:,1])
plt.xticks([])
plt.yticks([])
plt.show()

# %%
rips = Rips()
diagrams = rips.fit_transform(data)
rips.plot(diagrams,size=23)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# Un conjunto de puntos sobre un anillo

# %%
from sklearn.datasets import make_circles

X, y = make_circles(n_samples=200,noise=0.15)

plt.figure(dpi=120)
plt.scatter(X[:,0],X[:,1])
plt.xticks([])
plt.yticks([])
plt.show()

# %%
rips = Rips()
diagrams = rips.fit_transform(X)
rips.plot(diagrams,size=30)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# Un conjunto de puntos separado en dos componentes

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=500,centers=3,random_state=77)

plt.figure(dpi=120)
plt.scatter(X[:,0],X[:,1])
plt.xticks([])
plt.yticks([])
plt.show()

# %%
rips = Rips()
diagrams = rips.fit_transform(X)
rips.plot(diagrams,size=30)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# Combinando los anteriores

# %%
from sklearn.datasets import make_circles

X1, _ = make_circles(n_samples=300,noise=0.15,random_state=12)

noise = np.random.random(size=X1.shape)
X2 = X1 + np.array([3,3]) + 0.5*noise

noise = np.random.random(size=X1.shape)
X3 = X1 + np.array([2.5,-2]) + 0.5*noise

X = np.vstack((X1,X2,X3))

plt.figure(dpi=120)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
rips = Rips()
diagrams = rips.fit_transform(X)
rips.plot(diagrams,size=30)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
from sklearn.datasets import make_circles

X1, _ = make_circles(n_samples=300,noise=0.15,random_state=82)

noise = np.random.random(size=X1.shape)
X2 = X1 + np.array([3,3]) + 0.5*noise

noise = np.random.random(size=X1.shape)
X3 = X1 + np.array([2,-0.5]) + 0.5*noise

X = np.vstack((X1,X2,X3))

plt.figure(dpi=120)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
rips = Rips()
diagrams = rips.fit_transform(X)
rips.plot(diagrams,size=30)
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)
